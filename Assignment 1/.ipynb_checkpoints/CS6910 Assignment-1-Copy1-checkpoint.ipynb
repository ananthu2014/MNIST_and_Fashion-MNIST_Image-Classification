# %%
import wandb
import numpy  as np
import pandas as pd
import tensorflow as tf
from keras.datasets import fashion_mnist
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
import math
from sklearn.metrics import confusion_matrix
import seaborn as sns

# %%
wandb.login()
# Out:
# wandb: Currently logged in as: ananthu2014. Use `wandb login --relogin` to force relogin
# True

# %%
'''LOADING TRAIN AND TEST DATA SET'''
(X_train,Y_train),(X_test,Y_test) = fashion_mnist.load_data()

# %%
print(f'Shape of input train data is : {X_train.shape}')
print(f'Shape of input test data is : {X_test.shape}')
print(f'Shape of output train data is : {Y_train.shape}')
print(f'Shape of output test data is : {Y_test.shape}')
# Out:
# Shape of input train data is : (60000, 28, 28)
# Shape of input test data is : (10000, 28, 28)
# Shape of output train data is : (60000,)
# Shape of output test data is : (10000,)

# %%
'''Finding image of each category'''
categories=[]
images_list=[]
attributes={0:'T-shirt',1:'Trouser',2:'Pullover',3:'Skirt',4:'Overcoat',5:'Sandal',
            6:'Shirt',7:'Sneakers',8:'Bag',9:'Ankle boot'}
title=list(attributes.values())
print(f'The various categorical variables in the data are : {title}')
for i in range(10):
    categories.append(i)
for i in range(Y_train.shape[0]):
               if Y_train[i]==categories[0]:
                    images_list.append(X_train[i])
                    del(categories[0])
                    if len(categories)==0:
                        break
# Out:
# The various categorical variables in the data are : ['T-shirt', 'Trouser', 'Pullover', 'Skirt', 'Overcoat', 'Sandal', 'Shirt', 'Sneakers', 'Bag', 'Ankle boot']

# %%
'''Plotting image of each category'''
for i in range(len(attributes)):
    print(f'Numerical value equivalent to categorical variable : {Y_train[i]}')
    plt.imshow(images_list[i], cmap=plt.get_cmap())
    plt.title(attributes[i])
    plt.show()
# Out:
# Numerical value equivalent to categorical variable : 9
# Numerical value equivalent to categorical variable : 0
# Numerical value equivalent to categorical variable : 0
# Numerical value equivalent to categorical variable : 3
# Numerical value equivalent to categorical variable : 0
# Numerical value equivalent to categorical variable : 2
# Numerical value equivalent to categorical variable : 7
# Numerical value equivalent to categorical variable : 2
# Numerical value equivalent to categorical variable : 5
# Numerical value equivalent to categorical variable : 5

# %%
wandb.init(project="CS6910_DL_ASS1", name='Assignment_1_sample_imgs')
'''Displaying sample images in wandb'''
wandb.log({"Sample Image from each class": [wandb.Image(image, caption=caption) for image, 
                                            caption in zip(images_list,title)]})
# Out:
# Tracking run with wandb version 0.13.10
# Run data is saved locally in <code>C:\Users\anant\CS6910\Assignment 1\wandb\run-20230307_122123-e6r057tn</code>
# Syncing run <strong><a href='https://wandb.ai/ananthu2014/CS6910_DL_ASS1/runs/e6r057tn' target="_blank">Assignment_1_sample_imgs</a></strong> to <a href='https://wandb.ai/ananthu2014/CS6910_DL_ASS1' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/ananthu2014/CS6910_DL_ASS1' target="_blank">https://wandb.ai/ananthu2014/CS6910_DL_ASS1</a>
#  View run at <a href='https://wandb.ai/ananthu2014/CS6910_DL_ASS1/runs/e6r057tn' target="_blank">https://wandb.ai/ananthu2014/CS6910_DL_ASS1/runs/e6r057tn</a>

# %%
'''CHANGING THE SHAPE OF INPUT DATA'''
x_train=np.zeros((60000,784))
for i in range(X_train.shape[0]):
    a=X_train[i].reshape(1,784)
    x_train[i]=a
print('Train data',x_train.shape)
x_test=np.zeros((10000,784))
for i in range(X_test.shape[0]):
    a=X_test[i].reshape(1,784)
    x_test[i]=a
print('Test data',x_test.shape)
# Out:
# Train data (60000, 784)
# Test data (10000, 784)

# %%
'''CONVERTING OUTPUT DATA INTO ONE HOT VECTOR FORM'''
a = np.max(Y_train)+1
y_train=np.zeros((Y_train.shape[0],a))
for i in range(Y_train.shape[0]):
    for j in range(a):
        if Y_train[i]==j:
            y_train[i,j]=1
print('Train data',y_train.shape)
y_test=np.zeros((Y_test.shape[0],a))
for i in range(Y_test.shape[0]):
    for j in range(a):
        if Y_test[i]==j:
            y_test[i,j]=1
#print(y_test[0,:])
print('Test data',y_test.shape)
# Out:
# Train data (60000, 10)
# Test data (10000, 10)

# %%
'''CREATING VALIDATION DATA SET'''
'''The input data is split into train and validation data where validation comprises of 10% of the data.'''

x_train,x_val,y_train,y_val = train_test_split(x_train,y_train,test_size=0.10,random_state=0)
x_train=x_train.T/255
y_train=y_train.T
x_test=x_test.T/255
y_test=y_test.T
x_val=x_val.T/255
y_val=y_val.T
print(f'The shape of train data is:{x_train.shape}')
print(f'The shape of test data is:{x_test.shape}')
print(f'The shape of validation data is:{x_val.shape}')
# Out:
# The shape of train data is:(784, 54000)
# The shape of test data is:(784, 10000)
# The shape of validation data is:(784, 6000)

# %%
'''ACTIVATION FUNCTIONS'''

'''input: zl = w(l)*a(l-1) + b(l) where l is the lth Layer.The various activation functions implemented here are 
sigmoid,tanh,ReLu and Identity functions.'''


#SIGMOID FUNCTION
def sigmoid_function(z):
    h=1./(1.+np.exp(-z))
    
    return h

#TANH FUNCTION
def tanh_function(z):
    h=np.tanh(z)
    
    return h

#RELU FUNCTION
def relu_function(z):
    h=np.maximum(z,0)
    
    return h
    

#IDENTITY FUNCTION
def identity_function(z):
    
    return z

# %%
#OUTPUT LAYER FUNCTION
'''The given problem is a multi-class classification problem.So,we use softmax function for the output layer(L)
    Z(L) = W(L)*A(L-1) + B(L) where Lth layer is the output layer.'''


#SOFTMAX FUNCTION
'''OUTPUT LAYER FUNCTION'''

def softmax_function(z):
    h = np.exp(z)/np.sum(np.exp(z), axis=0)
    return h

# %%
'''DERIVATIVE FUNCTIONS'''

'''These are the derivatives of the corresponding activation functions, which is used in backpropogation to find
the derivative of activation functions.'''

#DERIVATIVE OF SIGMOID FUNCTION
def sigmoid_function_dash(z):
    h = sigmoid_function(z)
    
    return h*(1-h)


#DERIVATIVE OF TANH FUNCTION
def tanh_function_dash(z):
    h=tanh_function(z)
    
    return 1-(h)**2


#DERIVATIVE OF RELU FUNCTION
def relu_function_dash(z):
    return 1*(z>0)
    
#DERIVATIVE OF IDENTITY FUNCTION
def identity_function_dash(z):
    h = identity_function(z)
    
    return np.ones(z.shape)

# %%
'''SOFTMAX DERIVATIVE'''
def softmax_dash(Z):
    h= softmax(z) * (1-softmax(z))
    return h

# %%
#CROSS ENTROPY FUNCTION(DERIVATIVE OF OUTPUT LAYER)
def cross_entropy_function(y,ycap,w,lambd):
    '''This function is called as categorical cross entropy function.
       input: Y:actual value of output
              YCAP:predicted value of output
              lambd:Regularisation parameter(L2 Rregularization is used here)'''
    
    ycap = np.clip(ycap, 1e-12, 1.0 - 1e-12)
    m=y.shape[1]
    cost=-(1/m)*np.sum(y*np.log(ycap))
    regularization_cost=0
    for i in range(len(w)):
        regularization_cost += (lambd/(2*m))*np.sum(np.square(w[i]))
        
    return cost+regularization_cost
     
        
#MEAN SQUARED ERROR FUNCTION
def mean_squared_error_function(y,ycap,w,lambd):
    '''input: Y:actual value of output
              YCAP:predicted value of output
              lambd:Regularisation parameter(L2 Rregularization is used here)'''   
    m = y.shape[1]
    a=np.argmax(ycap,axis=0)
    b=np.argmax(y,axis=0)
    mean_square_error = (1/m)*np.sum((a-b)**2)
    reg_cost=0
    for i in range(len(w)):
        reg_cost += (lambd/(2*m))*np.sum(w[i]**2)
    return mean_square_error + reg_cost

# %%
#INITIALISE PARAMETERS

'''input:  Layer_attributes is a list consisting of number of 
    neurons in each layer. Here,input layer is considered as 0th Layer, output layer is considered as Lth layer
    and the layers from 1 to (L-1) are considered as hidden layers.Therefore, layer-attributes consists of (L+1)
    values. The methods used here to initialise the values of parameters are Random and Xavier Initialisations.'''

def random_initialization(layer_attributes):
    
    L=len(layer_attributes)-1
    W=[]
    B=[]
    np.random.seed(10)
    for i in range(1,L+1):
        weight_i = np.random.uniform(-1,1,(layer_attributes[i],layer_attributes[i-1]))
        bias_i=np.zeros((layer_attributes[i],1))
        W.append(weight_i)
        B.append(bias_i)
        
    return W,B

def xavier_initialization(layer_attributes):
    
    L=len(layer_attributes)-1
    W=[]
    B=[]
    for i in range(1,L+1):
        lim = np.sqrt(6/(i+(i-1)))
        weight_i = np.random.uniform(-lim,lim,(layer_attributes[i],layer_attributes[i-1]))
        bias_i=np.zeros((layer_attributes[i],1))
        W.append(weight_i)
        B.append(bias_i)
        
    return W,B

# %%
#FORWARD PROPOGATION
def forward_propogation(x,w,b,activation='sigmoid_function'):
    
    '''Forward propogation is used to find the predicted value of output and cost function by going forward,starting from 
    input layer until the output layer.We calculate the pre-activation and activation values and returns the latter after each
    layer. The input parameters taken are input data set,weights and bias value, and activation function to be used where the 
    default is set as sigmoid function. Softmax function is used to find the values at the output layer.
    Here,z is the linear part and a is the non-linear part(activation function) of a neuron.'''
    A=[]
    Z=[]
    length=len(w)
    #Hidden layers
    A.append(x)
    for i in range(length-1):
        z_i=np.dot(w[i],A[-1])+b[i]
        Z.append(z_i)
        if activation =='sigmoid_function':
            a_i = sigmoid_function(z_i)
            A.append(a_i)
        elif activation=='tanh_function':
            a_i = tanh_function(z_i)
            A.append(a_i)
        elif activation == 'relu_function':
            a_i = relu_function(z_i)
            A.append(a_i)
        elif activation == 'identity_function':
            a_i = identity_function(z_i)
            A.append(a_i)
    #output layer
    z_l = np.dot(w[-1],A[-1]) + b[-1]
    a_l = softmax_function(z_l)
    A.append(a_l)
    Z.append(z_l)

    return Z,A

# %%
#BACK PROPOGATION
def back_propogation(A,y,W,B,Z,lambd,activation='sigmoid_function',loss='cross_entropy_function'):
    
    '''Back propogation is used to find the derivatives of each weights and biases at each layers by starting 
    from the output layer and travelling backwards.We find the derivatives wrto ouput layer,wrto hidden layer and eventually
    wrto weights and biases;dw=dJ/dw,db=dJ/db,dz=dJ/dz.'''
    m=y.shape[1]
    L=len(W)
    dW=[]
    dB=[]
    dZ=[]
    #Output Layer
    if loss=='cross_entropy_function:'
        dZ.append(A[-1]-y)
        dB.append((1/m)*np.sum(dZ[-1],axis=1,keepdims=True))
        dW.append((1/m)*(np.dot(dZ[-1],A[-2].T))+(lambd/m)*W[-1])
    elif loss=='mean_squared_error_function':
        dZ.append((A[-1]-y)*A[-1]*(1-A[-1]))
        dB.append((1/m)*np.sum(dZ[-1],axis=1,keepdims=True))
        dW.append((1/m)*(np.dot(dZ[-1],A[-2].T))+(lambd/m)*W[-1])
        
   
    #Hidden layers
    l=L-1
    while l >0:
        if activation=='sigmoid_function':
            dz_l = (1/m)*np.dot(W[l].T,dZ[-1])*sigmoid_function_dash(A[l])
            db_l = (1/m)*np.sum(dz_l,axis=1,keepdims=True)
            dw_l = (1/m)*np.dot(dz_l,A[l-1].T) + (lambd/m)*W[l-1]
            dW.append(dw_l)
            dB.append(db_l)
            dZ.append(dz_l)
        
        elif activation == 'relu_function':
            dz_l = (1/m)*np.dot(W[l].T,dZ[-1])*relu_function_dash(A[l])
            db_l = (1/m)*np.sum(dz_l,axis=1,keepdims=True)
            dw_l = (1/m)*np.dot(dz_l,A[l-1].T) + (lambd/m)*W[l-1]
            dW.append(dw_l)
            dB.append(db_l)
            dZ.append(dz_l)
            
        elif activation=='tanh_function':
            dz_l = (1/m)*np.dot(W[l].T,dZ[-1])*tanh_function_dash(A[l])
            db_l = (1/m)*np.sum(dz_l,axis=1,keepdims=True)
            dw_l = (1/m)*np.dot(dz_l,A[l-1].T) + (lambd/m)*W[l-1]
            dW.append(dw_l)
            dB.append(db_l)
            dZ.append(dz_l)
            
        elif activation=='identity_function':
            dz_l = (1/m)*np.dot(W[l].T,dZ[-1])*identity_function_dash(A[l])
            db_l = (1/m)*np.sum(dz_l,axis=1,keepdims=True)
            dw_l = (1/m)*np.dot(dz_l,A[l-1].T) + (lambd/m)*W[l-1]
            dW.append(dw_l)
            dB.append(db_l)
            dZ.append(dz_l)
            
        l=l-1
            
    return dZ[::-1],dW[::-1],dB[::-1]
# Out:
#   File "C:\Users\anant\AppData\Local\Temp\ipykernel_13272\747797451.py", line 13
#     if loss=='cross_entropy_function:'
#                                       ^
# SyntaxError: invalid syntax

# %%
#OPTIMIZERS
def gradient_descent(W,B,dW,dB,learning_rate):
    
    '''Mini batch,vanilla and stochastic gradient descents can be performed for this basic 
    gradient descent variant.'''
    
    alpha=learning_rate
    length=len(W)
    for i in range(length):
        W[i] = W[i] - alpha*dW[i]
        B[i] = B[i] - alpha*dB[i]
    return W,B

def momentum_gradient_descent(w,b,dw,db,learning_rate,momentum,update_w,update_b):
    
    '''Nesterov accelarated gradient descent can also be implemented as a special case of this Momentum gradient
    descent  where we find wlookahead before calculating gradients '''
    
    for i in range(len(w)):  
        update_w[i] = (momentum*update_w[i]) + dw[i]
        update_b[i] = (momentum*update_b[i]) + db[i]
        w[i] = w[i] - (learning_rate*update_w[i])
        b[i] = b[i] - (learning_rate*update_b[i])
    return w,b,update_w,update_b

def rms_prop(w,b,dw,db,learning_rate,beta,epsilon,v_t_w,v_t_b):
    
    '''RMSProp is an adaptive learning algorithm and the hyperparamteters used 
    here are learning_rate(alpha) and beta.'''
    
    for i in range(len(w)):
        v_t_w[i] = beta*v_t_w[i] + (1-beta)*((dw[i])**2)
        v_t_b[i] = beta*v_t_b[i] + (1-beta)*((db[i])**2)
        w[i] = w[i] - (learning_rate/(np.sqrt(v_t_w[i]+epsilon)))*dw[i]
        b[i] = b[i] - (learning_rate/(np.sqrt(v_t_b[i]+epsilon)))*db[i]
        return w,b,v_t_w,v_t_b


def adam(w,b,dw,db,learning_rate,beta1,beta2,epsilon,m_w,m_b,v_w,v_b,t):
    
    '''Adam(Adaptive moments) is one of the widely used adaptive learning gradient descent variant and it takes 
    beta1,beta2,learning_rate(alpha) as hyperparameters and also a small value epsilon to avoid zero division
    errors.'''
    
    m_w_cap=[]
    m_b_cap=[]
    v_w_cap=[]
    v_b_cap=[]
    for k in range(len(w)):
        upd_w=np.zeros((w[k].shape))
        upd_b=np.zeros((b[k].shape))
        m_w_cap.append(upd_w)
        m_b_cap.append(upd_b)
        v_w_cap.append(upd_w)
        v_b_cap.append(upd_b)
        
    for i in range(len(w)):
        m_w[i]=beta1*m_w[i]+(1-beta1)*dw[i]
        m_b[i]=beta1*m_b[i]+(1-beta1)*db[i]
        v_w[i]=beta2*v_w[i]+(1-beta2)*(dw[i]**2)
        v_b[i]=beta2*v_b[i]+(1-beta2)*(db[i]**2)
        m_w_cap[i] = (1/(1-math.pow(beta1,t)))*m_w[i]
        m_b_cap[i] = (1/(1-math.pow(beta1,t)))*m_b[i]
        v_w_cap[i] = (1/(1-math.pow(beta2,t)))*v_w[i]
        v_b_cap[i] = (1/(1-math.pow(beta2,t)))*v_b[i]
        w[i] = w[i] - (learning_rate/(np.sqrt(v_w_cap[i]+epsilon)))*m_w_cap[i]
        b[i] = b[i] - (learning_rate/(np.sqrt(v_b_cap[i]+epsilon)))*m_b_cap[i]
        
    return w,b,m_w,m_b,v_w,v_b

def nadam(w,b,dw,db,learning_rate,beta1,beta2,epsilon,m_w,m_b,v_w,v_b,t):
    
    '''NAdam(Nesterov Adam) is the nesterov gradient variant of Adam'''
    
    m_w_cap=[]
    m_b_cap=[]
    v_w_cap=[]
    v_b_cap=[]
    for k in range(len(w)):
        upd_w=np.zeros((w[k].shape))
        upd_b=np.zeros((b[k].shape))
        m_w_cap.append(upd_w)
        m_b_cap.append(upd_b)
        v_w_cap.append(upd_w)
        v_b_cap.append(upd_b)
        
    for i in range(len(w)):
        
        m_w[i] = beta1*m_w[i] + (1-beta1)*dw[i]
        m_b[i] = beta1*m_b[i] + (1-beta1)*db[i]
        v_w[i] = beta2*v_w[i] + (1-beta2)*(dw[i])**2
        v_b[i] = beta2*v_b[i] + (1-beta2)*(db[i])**2
        m_w_cap[i] = (1/(1-beta1**t))*m_w[i]
        m_b_cap[i] = (1/(1-beta1**t))*m_b[i]
        v_w_cap[i] = (1/(1-beta2**t))*v_w[i]
        v_b_cap[i] = (1/(1-beta2**t))*v_b[i]
        w[i] = w[i]-(learning_rate/np.sqrt(v_w_cap[i]+epsilon))*(beta1*m_w_cap[i]+(1-beta1)*dw[i]/(1-beta1**t))
        b[i] = b[i]-(learning_rate/np.sqrt(v_b_cap[i]+epsilon))*(beta1*m_b_cap[i]+(1-beta1)*db[i]/(1-beta1**t))
        
    return w,b,m_w,m_b,v_w,v_b

# %%
#ACCURACY
def accuracy(y,yout):
    '''Function to find the accuracy taking y and ypred as input and returns accracy value.'''
    yout=np.argmax(yout,axis=0)
    y = np.argmax(y,axis=0)   
    acc=np.mean(y==yout)*100
    return acc

# %%
#FUNCTION FOR PLOTS
def plot_error(j_train, j_val):
    plt.plot(list(range(len(j_train))), j_train, 'r', label="Train Loss")
    plt.plot(list(range(len(j_val))), j_val, 'lime', label="Validation Loss")
    plt.title("Training and Validation Loss vs No. of Epochs", size=16)
    plt.xlabel("No. of epochs", size=16)
    plt.ylabel("Loss", size=16)
    plt.legend()
    plt.grid()
    plt.show()
    
def plot_accuracy(acc_train, acc_val):
    plt.plot(list(range(len(acc_train))), acc_train, 'r', label="Train Accuracy")
    plt.plot(list(range(len(acc_val))), acc_val, 'lime', label="Validation Accuracy")
    plt.title("Training and Validation Accuracy vs No. of Epochs", size=16)
    plt.xlabel("No. of epochs", size=16)
    plt.ylabel("Accuracy", size=16)
    plt.legend()
    plt.grid()
    plt.show()

# %%
 #PREDICT FUNCTION
def predict(x,y,w,b,lambd,activation):
    '''This function is to predict the cost and accuracy values of the test data
       input :  x(input)
                y(output)
                w,b(weights and biases)
                lamb(regularisation parameter)
                loss(loss function)
                activation(activation function)'''
    
    z,a = forward_propogation(x_train,w,b,activation)
    acc= accuracy(y,a[-1])
    y_pred=np.argmax(a[-1],axis=0)
    Y=np.argmax(y,axis=0)
            
    return y_pred,Y,acc

# %%
# def neural_network(x_train,y_train,x_val,y_val,learning_rate = 0.1,momentum = 0.5,beta=0.5,beta1=0.5,beta2=0.5,epochs = 1,num_hidden_layers = 1,neurons=4,batch_size=4,epsilon=0.00000001,weight_init='random_initialization',
#                    activation='sigmoid_function',loss='cross_entropy_function',optimizer='stochastic_gradient_descent',lambd=0):
def neural_network():
    
    # Default values for hyper-parameters
    config_defaults = {
        'learning_rate': 0.1,
        'activation': 'sigmoid_function',
        'weight_init': 'random_initialization',
        'optimizer': 'stochastic_gradient_descent',
        'batch_size': 4,
        'epochs': 10,
        'lambd': 0,
        'neurons': 4,
        'num_hidden_layers': 1,
        'momentum':0.5,
        'beta':0.5,
        'beta1':0.5,
        'beta2':0.5,
        'loss':'cross_entropy_function'
        }


    wandb.init(config=config_defaults)
    config = wandb.config

    learning_rate = config.learning_rate
    activation = config.activation
    weight_init = config.weight_init
    optimizer = config.optimizer
    batch_size = config.batch_size
    epochs = config.epochs
    lambd = config.lambd
    neurons = config.neurons
    num_hidden_layers = config.num_hidden_layers
    momentum=config.momentum
    beta = config.beta
    beta1=config.beta1
    beta2=config.beta2
    loss=config.loss
    
    run_name= f'lr_{learning_rate}_acti_{activation}_w_in{weight_init}_opt_{optimizer}_epoch_{epochs}_num_hid_{num_hidden_layers}_loss_{loss}_batchsize_{batch_size}_neur_{neurons}_lam_{lambd}_momentum_{momentum}_beta_{beta}_beta1_{beta1}_beta2_{beta2}'
    print(run_name)
    
    epsilon=0.00000001
    layer=[]
    n,m=x_train.shape
    J_train=[]
    Accuracy_train=[]
    J_val=[]
    Accuracy_val=[]
    acc_train=0
    acc_val=0
    layer.append(x_train.shape[0])
    for i in range(num_hidden_layers):
        layer.append(neurons)
    layer.append(y_train.shape[0])
    print(f'neuron configuration: {layer}')
    if weight_init=='random_initialization':
        w,b=random_initialization(layer)
    elif weight_init=='xavier_initialization':
        w,b=xavier_initialization(layer)
    update_w=[]
    update_b=[]
    w_lookahead=[]
    b_lookahead=[]
    v_t_w=[]
    v_t_b=[]
    m_w=[]
    m_b=[]
    v_w=[]
    v_b=[]
    for k in range(len(w)):
        upd_w=np.zeros((w[k].shape))
        upd_b=np.zeros((b[k].shape))
        update_w.append(upd_w)
        w_lookahead.append(upd_w)
        update_b.append(upd_b)
        b_lookahead.append(upd_b)
        v_t_w.append(upd_w)
        v_t_b.append(upd_b)
        m_w.append(upd_w)
        m_b.append(upd_b)
        v_w.append(upd_w)
        v_b.append(upd_b)
        
    num_batches = x_train.shape[1]//batch_size
    
    if optimizer=='vanilla_gradient_descent':
        
        for j in range(epochs):
            z,a = forward_propogation(x_train,w,b,activation)
            dz,dw,db=back_propogation(a,y_train,w,b,z,lambd,activation,loss)
            w,b=gradient_descent(w,b,dw,db,learning_rate)
            if loss=='cross_entropy_function':
                
                cost_train=cross_entropy_function(y_train,a[-1],w,lambd)
                J_train.append(cost_train)
                acc_train = accuracy(y_train,a[-1])
                Accuracy_train.append(acc_train)
                z_val,a_val = forward_propogation(x_val,w,b,activation)
                cost_val = cross_entropy_function(y_val,a_val[-1],w,lambd)
                J_val.append(cost_val)
                acc_val=accuracy(y_val,a_val[-1])
                Accuracy_val.append(acc_val)
            elif loss=='mean_squared_error_function':
                
                cost_train=mean_squared_error_function(y_train,a[-1],w,lambd)
                J_train.append(cost_train)
                acc_train = accuracy(y_train,a[-1])
                Accuracy_train.append(acc_train)
                z_val,a_val = forward_propogation(x_val,w,b,activation)
                cost_val = mean_squared_error_function(y_val,a_val[-1],w,lambd)
                J_val.append(cost_val)
                acc_val = accuracy(y_val,a_val[-1])
                Accuracy_val.append(acc_val)
            wandb.log({"accuracy_train": acc_train, "accuracy_validation": acc_val, "loss_train": cost_train, "cost_validation": cost_val, 'epochs': j})
            
            if j%(epochs/10)==0:
                print(f' \n epoch:{j:4d}  Train error:  {J_train[-1]:8.2f}  Train accuracy: {Accuracy_train[-1]:8.2f} Val error: {J_val[-1]:8.2f} Val accuracy: {Accuracy_val[-1]:8.2f}')
            #if j%((epochs/10)/5)==0:
                #print('==',end='')
            
    if optimizer=='stochastic_gradient_descent':
        
        
        for j in range(epochs):
            for i in range(m):
                x_data = x_train[:,i].reshape(x_train.shape[0],1)
                y_data = y_train[:,i].reshape(y_train.shape[0],1)
                z,a = forward_propogation(x_data,w,b,activation)
                dz,dw,db=back_propogation(a,y_data,w,b,z,lambd,activation,loss)
                w,b=gradient_descent(w,b,dw,db,learning_rate)
            z,a = forward_propogation(x_train,w,b,activation)
            cost_train=cross_entropy_function(y_train,a[-1],w,lambd)
            J_train.append(cost_train)
            acc_train = accuracy(y_train,a[-1])
            Accuracy_train.append(acc_train)
            z_val,a_val = forward_propogation(x_val,w,b,activation)
            cost_val = cross_entropy_function(y_val,a_val[-1],w,lambd)
            J_val.append(cost_val)
            acc_val = accuracy(y_val,a_val[-1])
            wandb.log({"accuracy_train": acc_train, "accuracy_validation": acc_val, "loss_train": cost_train, "cost_validation": cost_val, 'epochs': j})
            Accuracy_val.append(acc_val)
            if j%(epochs/10)==0:
                print(f' \n epoch:{j:4d}  Train error:  {J_train[-1]:8.2f}  Train accuracy: {Accuracy_train[-1]:8.2f} Val error: {J_val[-1]:8.2f} Val accuracy: {Accuracy_val[-1]:8.2f}')
            #if j%((epochs/10)/5)==0:
                #print('==',end='')
            
    if optimizer=='momentum_gradient_descent':
            
        for j in range(epochs):
            
            for i in range(num_batches):
                x_mb = x_train[:,i*batch_size:(i+1)*batch_size].reshape(x_train.shape[0],batch_size)
                y_mb = y_train[:,i*batch_size:(i+1)*batch_size].reshape(y_train.shape[0],batch_size)
                z,a = forward_propogation(x_mb,w,b,activation)
                dz,dw,db=back_propogation(a,y_mb,w,b,z,lambd,activation,loss)
                w,b,update_w,update_b = momentum_gradient_descent(w,b,dw,db,learning_rate,momentum,update_w,update_b)
            if x_train.shape[1] % batch_size !=0:
                x_last = x_train[:,num_batches*batch_size:]
                y_last = y_train[:,num_batches*batch_size:]
                z,a = forward_propogation(x_last,w,b,activation)
                dz,dw,db=back_propogation(a,y_last,w,b,z,lambd,activation,loss)
                w,b,update_w,update_b = momentum_gradient_descent(w,b,dw,db,learning_rate,momentum,update_w,update_b)
            z,a = forward_propogation(x_train,w,b,activation)
            if loss=='cross_entropy_function':
                
                cost_train=cross_entropy_function(y_train,a[-1],w,lambd)
                J_train.append(cost_train)
                acc_train = accuracy(y_train,a[-1])
                Accuracy_train.append(acc_train)
                z_val,a_val = forward_propogation(x_val,w,b,activation)
                cost_val = cross_entropy_function(y_val,a_val[-1],w,lambd)
                J_val.append(cost_val)
                acc_val=accuracy(y_val,a_val[-1])
                Accuracy_val.append(acc_val)
            elif loss=='mean_squared_error_function':
                
                cost_train=mean_squared_error_function(y_train,a[-1],w,lambd)
                J_train.append(cost_train)
                acc_train = accuracy(y_train,a[-1])
                Accuracy_train.append(acc_train)
                z_val,a_val = forward_propogation(x_val,w,b,activation)
                cost_val = mean_squared_error_function(y_val,a_val[-1],w,lambd)
                J_val.append(cost_val)
                acc_val = accuracy(y_val,a_val[-1])
                Accuracy_val.append(acc_val)
            wandb.log({"accuracy_train": acc_train, "accuracy_validation": acc_val, "loss_train": cost_train, "cost_validation": cost_val, 'epochs': j})
            
            if j%(epochs/10)==0:
                print(f' \n epoch:{j:4d}  Train error:  {J_train[-1]:8.2f}  Train accuracy: {Accuracy_train[-1]:8.2f} Val error: {J_val[-1]:8.2f} Val accuracy: {Accuracy_val[-1]:8.2f}')
            #if j%((epochs/10)/5)==0:
                #print('==',end='')
                
                
    if optimizer == 'nesterov_accelarated_gradient_descent':
        
        for j in range(epochs):
            
            for i in range(num_batches):
                x_mb = x_train[:,i*batch_size:(i+1)*batch_size].reshape(x_train.shape[0],batch_size)
                y_mb = y_train[:,i*batch_size:(i+1)*batch_size].reshape(y_train.shape[0],batch_size)
                for i in range(len(w)):
                    w_lookahead[i] = w[i]-momentum*update_w[i]
                    b_lookahead[i] = b[i]-momentum*update_b[i]
                z,a = forward_propogation(x_mb,w_lookahead,b_lookahead,activation)
                dz,dw,db=back_propogation(a,y_mb,w_lookahead,b_lookahead,z,lambd,activation,loss)
                w,b,update_w,update_b = momentum_gradient_descent(w,b,dw,db,learning_rate,momentum,update_w,update_b)
            if x_train.shape[1] % batch_size !=0:
                x_last = x_train[:,num_batches*batch_size:]
                y_last = y_train[:,num_batches*batch_size:]
                z,a = forward_propogation(x_last,w_lookahead,b_lookahead,activation)
                dz,dw,db=back_propogation(a,y_last,w_lookahead,b_lookahead,z,lambd,activation,loss)
                w,b,update_w,update_b = momentum_gradient_descent(w,b,dw,db,learning_rate,momentum,update_w,update_b)
                
            z,a = forward_propogation(x_train,w,b,activation)
            if loss=='cross_entropy_function':
                
                cost_train=cross_entropy_function(y_train,a[-1],w,lambd)
                J_train.append(cost_train)
                acc_train = accuracy(y_train,a[-1])
                Accuracy_train.append(acc_train)
                z_val,a_val = forward_propogation(x_val,w,b,activation)
                cost_val = cross_entropy_function(y_val,a_val[-1],w,lambd)
                J_val.append(cost_val)
                acc_val=accuracy(y_val,a_val[-1])
                Accuracy_val.append(acc_val)
            elif loss=='mean_squared_error_function':
                
                cost_train=mean_squared_error_function(y_train,a[-1],w,lambd)
                J_train.append(cost_train)
                acc_train = accuracy(y_train,a[-1])
                Accuracy_train.append(acc_train)
                z_val,a_val = forward_propogation(x_val,w,b,activation)
                cost_val = mean_squared_error_function(y_val,a_val[-1],w,lambd)
                J_val.append(cost_val)
                acc_val = accuracy(y_val,a_val[-1])
                Accuracy_val.append(acc_val)
            wandb.log({"accuracy_train": acc_train, "accuracy_validation": acc_val, "loss_train": cost_train, "cost_validation": cost_val, 'epochs': j})
            
            if j%(epochs/10)==0:
                print(f' \n epoch:{j:4d}  Train error:  {J_train[-1]:8.2f}  Train accuracy: {Accuracy_train[-1]:8.2f} Val error: {J_val[-1]:8.2f} Val accuracy: {Accuracy_val[-1]:8.2f}')
            #if j%((epochs/10)/5)==0:
                #print('==',end='')
                
                
    if optimizer == 'rms_prop':
            
        for j in range(epochs):
            
            for i in range(num_batches):
                x_mb = x_train[:,i*batch_size:(i+1)*batch_size].reshape(x_train.shape[0],batch_size)
                y_mb = y_train[:,i*batch_size:(i+1)*batch_size].reshape(y_train.shape[0],batch_size)
                z,a = forward_propogation(x_mb,w,b,activation)
                dz,dw,db=back_propogation(a,y_mb,w,b,z,lambd,activation,loss)
                w,b,v_t_w,v_t_b = rms_prop(w,b,dw,db,learning_rate,beta,epsilon,v_t_w,v_t_b)
            if x_train.shape[1] % batch_size !=0:
                x_last = x_train[:,num_batches*batch_size:]
                y_last = y_train[:,num_batches*batch_size:]
                z,a = forward_propogation(x_last,w,b,activation)
                dz,dw,db=back_propogation(a,y_last,w,b,z,lambd,activation,loss)
                w,b,v_t_w,v_t_b = rms_prop(w,b,dw,db,learning_rate,beta,epsilon,v_t_w,v_t_b)
            z,a = forward_propogation(x_train,w,b,activation)
            if loss=='cross_entropy_function':
                
                cost_train=cross_entropy_function(y_train,a[-1],w,lambd)
                J_train.append(cost_train)
                acc_train = accuracy(y_train,a[-1])
                Accuracy_train.append(acc_train)
                z_val,a_val = forward_propogation(x_val,w,b,activation)
                cost_val = cross_entropy_function(y_val,a_val[-1],w,lambd)
                J_val.append(cost_val)
                acc_val=accuracy(y_val,a_val[-1])
                Accuracy_val.append(acc_val)
            elif loss=='mean_squared_error_function':
                
                cost_train=mean_squared_error_function(y_train,a[-1],w,lambd)
                J_train.append(cost_train)
                acc_train = accuracy(y_train,a[-1])
                Accuracy_train.append(acc_train)
                z_val,a_val = forward_propogation(x_val,w,b,activation)
                cost_val = mean_squared_error_function(y_val,a_val[-1],w,lambd)
                J_val.append(cost_val)
                acc_val = accuracy(y_val,a_val[-1])
                Accuracy_val.append(acc_val)
            wandb.log({"accuracy_train": acc_train, "accuracy_validation": acc_val, "loss_train": cost_train, "cost_validation": cost_val, 'epochs': j})
            
            if j%(epochs/10)==0:
                print(f' \n epoch:{j:4d}  Train error:  {J_train[-1]:8.2f}  Train accuracy: {Accuracy_train[-1]:8.2f} Val error: {J_val[-1]:8.2f} Val accuracy: {Accuracy_val[-1]:8.2f}')
            #if j%((epochs/10)/5)==0:
                #print('==',end='')
                
                
                
    if optimizer == 'adam':
        for  j in range(epochs):
            
            for i in range(num_batches):
                x_mb = x_train[:,i*batch_size:(i+1)*batch_size].reshape(x_train.shape[0],batch_size)
                y_mb = y_train[:,i*batch_size:(i+1)*batch_size].reshape(y_train.shape[0],batch_size)
                z,a = forward_propogation(x_mb,w,b,activation)
                dz,dw,db=back_propogation(a,y_mb,w,b,z,lambd,activation,loss)
                w,b,m_w,m_b,v_w,v_b = adam(w,b,dw,db,learning_rate,beta1,beta2,epsilon,m_w,m_b,v_w,v_b,j+1)
            if x_train.shape[1] % batch_size !=0:
                x_last = x_train[:,num_batches*batch_size:]
                y_last = y_train[:,num_batches*batch_size:]
                z,a = forward_propogation(x_last,w,b,activation)
                dz,dw,db=back_propogation(a,y_last,w,b,z,lambd,activation,loss)
                w,b,m_w,m_b,v_w,v_b = adam(w,b,dw,db,learning_rate,beta1,beta2,epsilon,m_w,m_b,v_w,v_b,j+1)
            z,a=forward_propogation(x_train,w,b,activation)
            if loss=='cross_entropy_function':
                
                cost_train=cross_entropy_function(y_train,a[-1],w,lambd)
                J_train.append(cost_train)
                acc_train = accuracy(y_train,a[-1])
                Accuracy_train.append(acc_train)
                z_val,a_val = forward_propogation(x_val,w,b,activation)
                cost_val = cross_entropy_function(y_val,a_val[-1],w,lambd)
                J_val.append(cost_val)
                acc_val=accuracy(y_val,a_val[-1])
                Accuracy_val.append(acc_val)
            elif loss=='mean_squared_error_function':
                
                cost_train=mean_squared_error_function(y_train,a[-1],w,lambd)
                J_train.append(cost_train)
                acc_train = accuracy(y_train,a[-1])
                Accuracy_train.append(acc_train)
                z_val,a_val = forward_propogation(x_val,w,b,activation)
                cost_val = mean_squared_error_function(y_val,a_val[-1],w,lambd)
                J_val.append(cost_val)
                acc_val = accuracy(y_val,a_val[-1])
                Accuracy_val.append(acc_val)
            wandb.log({"accuracy_train": acc_train, "accuracy_validation": acc_val, "loss_train": cost_train, "cost_validation": cost_val, 'epochs': j})
            
            if j%(epochs/10)==0:
                print(f' \n epoch:{j:4d}  Train error:  {J_train[-1]:8.2f}  Train accuracy: {Accuracy_train[-1]:8.2f} Val error: {J_val[-1]:8.2f} Val accuracy: {Accuracy_val[-1]:8.2f}')
            #if j%((epochs/10)/5)==0:
                #print('==',end='')
                
                
    if optimizer =='nadam':
        for  j in range(epochs):
            
            for i in range(num_batches):
                x_mb = x_train[:,i*batch_size:(i+1)*batch_size].reshape(x_train.shape[0],batch_size)
                y_mb = y_train[:,i*batch_size:(i+1)*batch_size].reshape(y_train.shape[0],batch_size)
                z,a = forward_propogation(x_mb,w,b,activation)
                dz,dw,db=back_propogation(a,y_mb,w,b,z,lambd,activation,loss)
                w,b,m_w,m_b,v_w,v_b = nadam(w,b,dw,db,learning_rate,beta1,beta2,epsilon,m_w,m_b,v_w,v_b,j+1)
            if x_train.shape[1] % batch_size !=0:
                x_last = x_train[:,num_batches*batch_size:]
                y_last = y_train[:,num_batches*batch_size:]
                z,a = forward_propogation(x_last,w,b,activation)
                dz,dw,db=back_propogation(a,y_last,w,b,z,lambd,activation,loss)
                w,b,m_w,m_b,v_w,v_b = nadam(w,b,dw,db,learning_rate,beta1,beta2,epsilon,m_w,m_b,v_w,v_b,j+1)
            z,a=forward_propogation(x_train,w,b,activation)
            
            if loss=='cross_entropy_function':
                
                cost_train=cross_entropy_function(y_train,a[-1],w,lambd)
                J_train.append(cost_train)
                acc_train = accuracy(y_train,a[-1])
                Accuracy_train.append(acc_train)
                z_val,a_val = forward_propogation(x_val,w,b,activation)
                cost_val = cross_entropy_function(y_val,a_val[-1],w,lambd)
                J_val.append(cost_val)
                acc_val=accuracy(y_val,a_val[-1])
                Accuracy_val.append(acc_val)
            elif loss=='mean_squared_error_function':
                
                cost_train=mean_squared_error_function(y_train,a[-1],w,lambd)
                J_train.append(cost_train)
                acc_train = accuracy(y_train,a[-1])
                Accuracy_train.append(acc_train)
                z_val,a_val = forward_propogation(x_val,w,b,activation)
                cost_val = mean_squared_error_function(y_val,a_val[-1],w,lambd)
                J_val.append(cost_val)
                acc_val = accuracy(y_val,a_val[-1])
                Accuracy_val.append(acc_val)
            wandb.log({"accuracy_train": acc_train, "accuracy_validation": acc_val, "loss_train": cost_train, "cost_validation": cost_val, 'epochs': j})
            
            if j%(epochs/10)==0:
                print(f' \n epoch:{j:4d}  Train error:  {J_train[-1]:8.2f}  Train accuracy: {Accuracy_train[-1]:8.2f} Val error: {J_val[-1]:8.2f} Val accuracy: {Accuracy_val[-1]:8.2f}')
            #if j%((epochs/10)/5)==0:
                #print('==',end='')
        
            
            
    plot_error(J_train,J_val)
    plot_accuracy(Accuracy_train,Accuracy_val)
    return w,b,J_train,J_val
    
    wandb.run.name = run_name
    wandb.run.save()
    wandb.run.finish()

# %%
'''Adam algorithm'''
#neural_network(x_train,y_train,x_val,y_val,learning_rate=0.01,beta1=0.9,beta2=0.99,optimizer='adam',epochs=10,neurons=784,lambd=0,batch_size=256)
# Out:
# 'Adam algorithm'

# %%
'''Nesterov_Adam algorithm'''
neural_network(x_train,y_train,x_val,y_val,learning_rate=0.0001,lambd=0,beta1=0.9,beta2=0.99,optimizer='nadam',epochs=10,neurons=64,batch_size=256)

# %%
'''Momentum gradient descent'''
_,_,_,_=neural_network(x_train,y_train,x_val,y_val,activation='relu_function',loss='mean_squared_error_function',learning_rate=0.001,optimizer='momentum_gradient_descent',batch_size=32,lambd=0,momentum=0.9,epochs=10,neurons=64,num_hidden_layers=2)

# %%
'''Vanilla Gradient Descent'''
_,_,_,_=neural_network(x_train,y_train,x_val,y_val,loss='mean_squared_error_function',optimizer='vanilla_gradient_descent',epochs=10,neurons=64,num_hidden_layers=1,batch_size=256)

# %%
'''Stochastic gradient descent'''
neural_network(x_train,y_train,x_val,y_val,optimizer='stochastic_gradient_descent',epochs=20,learning_rate=0.00001,neurons=128)

# %%
'''Nesterov accelarated gradient descent(NAG)'''
_,_,_,_=neural_network(x_train,y_train,x_val,y_val,learning_rate=0.01,optimizer='nesterov_accelarated_gradient_descent',epochs=10,batch_size=128,momentum=0.9,neurons=64)

# %%
'''RMSProp'''
neural_network(x_train,y_train,x_val,y_val,optimizer='rms_prop',epochs=10,neurons=784,beta=0.9,learning_rate=0.01,batch_size=64)

# %%
'''Adam algorithm with relu activation function'''
neural_network(x_train,y_train,x_val,y_val,learning_rate=0.001,beta1=0.9,beta2=0.99,optimizer='adam',epochs=10,neurons=784,lambd=0,batch_size=256,activation='relu_function')

# %%
'''Adam algorithm with tanh activation function'''
neural_network(x_train,y_train,x_val,y_val,learning_rate=0.001,beta1=0.9,beta2=0.99,optimizer='adam',epochs=10,neurons=784,lambd=0,batch_size=256,activation='tanh_function')

# %%
'''Adam algorithm with identity activation function'''
neural_network(x_train,y_train,x_val,y_val,learning_rate=0.001,beta1=0.9,beta2=0.99,optimizer='adam',lambd=0,epochs=10,neurons=784,batch_size=256,activation='identity_function')

# %%
sweep_config = {
  "name": "Loss and Accuracy",
  "metric": {
      "name":"accuracy_validation",
      "goal": "maximize"
  },
  "method": "random",
  "parameters": {
        "learning_rate": {
            "values": [0.1,0.01,0.001, 0.0001,0.00001]
        },
        "activation": {
            "values": ["sigmoid_function", "relu_function", "tanh_function","identity_function"]
        },
        "weight_init": {
            "values": ["xavier_initialization", "random_initialization"]
        },
        "optimizer": {
            "values": ["stochastic_gradient_descent", "momentum_gradient_descent", "nesterov_accelarated_gradient_descent", "adam", "nadam", "rms_prop"]
        },
        "batch_size": {
            "values": [16,32,64]
        },
        "epochs": {
            "values": [10,20,40]
        },
        "lambd": {
            "values": [0, 0.0005, 0.01]
        },
        "neurons": {
            "values": [16,32,64]
        },
        "num_hidden_layers": {
            "values": [1,2]
        },
        "momentum": {
            "values": [0.8,0.9]
        },
        "beta": {
            "values": [0.9]
        },
        "beta1": {
            "values": [0.9]
        },
        "beta2": {
            "values": [0.99]
        },
        "loss": {
            "values": ['cross_entropy_function','mean_squared_error_function']
        }
    }
}

sweep_id = wandb.sweep(sweep_config, project="CS6910_DL_ASS1")
wandb.agent(sweep_id, neural_network, count=200)

# %%
sweep_config = {
  "name": "Loss and Accuracy",
  "metric": {
      "name":"accuracy_validation",
      "goal": "maximize"
  },
  "method": "bayes",
  "parameters": {
        "learning_rate": {
            "values": [0.01,0.001]
        },
        "activation": {
            "values": ["sigmoid_function", "relu_function", "tanh_function"]
        },
        "weight_init": {
            "values": ["xavier_initialization", "random_initialization"]
        },
        "optimizer": {
            "values": ["stochastic_gradient_descent", "momentum_gradient_descent","nadam", "nesterov_accelarated_gradient_descent", "adam", "rms_prop"]
        },
        "batch_size": {
            "values": [4,8,16]
        },
        "epochs": {
            "values": [10,20]
        },
        "lambd": {
            "values": [0, 0.001]
        },
        "neurons": {
            "values": [32,64,128]
        },
        "num_hidden_layers": {
            "values": [1,2]
        },
        "momentum": {
            "values": [0.9]
        },
        "beta": {
            "values": [0.9]
        },
        "beta1": {
            "values": [0.9]
        },
        "beta2": {
            "values": [0.99]
        },
        "loss": {
            "values": ['cross_entropy_function']
        }
    }
}

sweep_id = wandb.sweep(sweep_config, project="CS6910_DL_ASS1")
wandb.agent(sweep_id, neural_network, count=100)

# %%
sweep_config = {
  "name": "Loss and Accuracy-Highest validation accuracy",
  "metric": {
      "name":"accuracy_validation",
      "goal": "maximize"
  },
  "method": "grid",
  "parameters": {
        "learning_rate": {
            "values": [0.001,0.0001]
        },
        "activation": {
            "values": ["relu_function"]
        },
        "weight_init": {
            "values": ["random_initialization"]
        },
        "optimizer": {
            "values": ["adam","nadam"]
        },
        "batch_size": {
            "values": [4,8]
        },
        "epochs": {
            "values": [10,20]
        },
        "lambd": {
            "values": [0,0.001]
        },
        "neurons": {
            "values": [64]
        },
        "num_hidden_layers": {
            "values": [1]
        },
        "momentum": {
            "values": [0.9]
        },
        "beta": {
            "values": [0.9]
        },
        "beta1": {
            "values": [0.9]
        },
        "beta2": {
            "values": [0.99]
        },
        "loss": {
            "values": ['cross_entropy_function']
        }
    }
}

sweep_id = wandb.sweep(sweep_config, project="CS6910_DL_ASS1")
wandb.agent(sweep_id, neural_network)

# %%
sweep_config = {
  "name": "Loss and Accuracy-Highest validation accuracy",
  "metric": {
      "name":"accuracy_validation",
      "goal": "maximize"
  },
  "method": "grid",
  "parameters": {
        "learning_rate": {
            "values": [0.001]
        },
        "activation": {
            "values": ["relu_function"]
        },
        "weight_init": {
            "values": ["random_initialization"]
        },
        "optimizer": {
            "values": ["adam","nadam"]
        },
        "batch_size": {
            "values": [4,8,16]
        },
        "epochs": {
            "values": [20,40]
        },
        "lambd": {
            "values": [0]
        },
        "neurons": {
            "values": [64,128]
        },
        "num_hidden_layers": {
            "values": [1]
        },
        "momentum": {
            "values": [0.9]
        },
        "beta": {
            "values": [0.9]
        },
        "beta1": {
            "values": [0.9]
        },
        "beta2": {
            "values": [0.99]
        },
        "loss": {
            "values": ['cross_entropy_function']
        }
    }
}

sweep_id = wandb.sweep(sweep_config, project="CS6910_DL_ASS1")
wandb.agent(sweep_id, neural_network)

# %%
'''HIGHEST ACCURACY PLOT
LEARNING RATE:0.001
EPOCHS:20
OPTIMIZER:Nesterov Adam
REGULARIZATION PARAMETER:0
ACTIVATION FUNCTION:RELu function
BETA1:0.9
BETA2:0.99
INITIALIZATION:RANDOM
LOSS FUNCTION:CROSS-ENTROPY
BATCH SIZE:16
NEURONS:64
HIDDEN LAYERS:1'''
sweep_config = {
  "name": "Loss and Accuracy-Highest validation accuracy",
  "metric": {
      "name":"accuracy_validation",
      "goal": "maximize"
  },
  "method": "grid",
  "parameters": {
        "learning_rate": {
            "values": [0.001]
        },
        "activation": {
            "values": ["relu_function"]
        },
        "weight_init": {
            "values": ["random_initialization"]
        },
        "optimizer": {
            "values": ["nadam"]
        },
        "batch_size": {
            "values": [16]
        },
        "epochs": {
            "values": [20,40]
        },
        "lambd": {
            "values": [0]
        },
        "neurons": {
            "values": [64]
        },
        "num_hidden_layers": {
            "values": [1]
        },
        "momentum": {
            "values": [0.9]
        },
        "beta": {
            "values": [0.9]
        },
        "beta1": {
            "values": [0.9]
        },
        "beta2": {
            "values": [0.99]
        },
        "loss": {
            "values": ['cross_entropy_function']
        }
    }
}

sweep_id = wandb.sweep(sweep_config, project="CS6910_DL_ASS1")
wandb.agent(sweep_id, neural_network)
# Out:
# Create sweep with ID: 70xah3nu
# Sweep URL: https://wandb.ai/ananthu2014/CS6910_DL_ASS1/sweeps/70xah3nu
# wandb: Agent Starting Run: gx1y65pl with config:
# wandb: 	activation: relu_function
# wandb: 	batch_size: 16
# wandb: 	beta: 0.9
# wandb: 	beta1: 0.9
# wandb: 	beta2: 0.99
# wandb: 	epochs: 20
# wandb: 	lambd: 0
# wandb: 	learning_rate: 0.001
# wandb: 	loss: cross_entropy_function
# wandb: 	momentum: 0.9
# wandb: 	neurons: 64
# wandb: 	num_hidden_layers: 1
# wandb: 	optimizer: nadam
# wandb: 	weight_init: random_initialization
# Tracking run with wandb version 0.13.10
# Run data is saved locally in <code>C:\Users\anant\CS6910\Assignment 1\wandb\run-20230307_141047-gx1y65pl</code>
# Syncing run <strong><a href='https://wandb.ai/ananthu2014/CS6910_DL_ASS1/runs/gx1y65pl' target="_blank">magic-sweep-1</a></strong> to <a href='https://wandb.ai/ananthu2014/CS6910_DL_ASS1' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>Sweep page: <a href='https://wandb.ai/ananthu2014/CS6910_DL_ASS1/sweeps/70xah3nu' target="_blank">https://wandb.ai/ananthu2014/CS6910_DL_ASS1/sweeps/70xah3nu</a>
#  View project at <a href='https://wandb.ai/ananthu2014/CS6910_DL_ASS1' target="_blank">https://wandb.ai/ananthu2014/CS6910_DL_ASS1</a>
#  View sweep at <a href='https://wandb.ai/ananthu2014/CS6910_DL_ASS1/sweeps/70xah3nu' target="_blank">https://wandb.ai/ananthu2014/CS6910_DL_ASS1/sweeps/70xah3nu</a>
#  View run at <a href='https://wandb.ai/ananthu2014/CS6910_DL_ASS1/runs/gx1y65pl' target="_blank">https://wandb.ai/ananthu2014/CS6910_DL_ASS1/runs/gx1y65pl</a>
# lr_0.001_acti_relu_function_w_inrandom_initialization_opt_nadam_epoch_20_num_hid_1_loss_cross_entropy_function_batchsize_16_neur_64_lam_0_momentum_0.9_beta_0.9_beta1_0.9_beta2_0.99
# neuron configuration: [784, 64, 10]
#
#  epoch:   0  Train error:      0.57  Train accuracy:    81.08 Val error:     0.61 Val accuracy:    79.70
#
#  epoch:   2  Train error:      0.41  Train accuracy:    85.51 Val error:     0.45 Val accuracy:    84.17
#
#  epoch:   4  Train error:      0.37  Train accuracy:    86.91 Val error:     0.41 Val accuracy:    85.52
#
#  epoch:   6  Train error:      0.34  Train accuracy:    87.56 Val error:     0.40 Val accuracy:    86.23
#
#  epoch:   8  Train error:      0.32  Train accuracy:    88.15 Val error:     0.39 Val accuracy:    86.48
#
#  epoch:  10  Train error:      0.31  Train accuracy:    88.66 Val error:     0.38 Val accuracy:    86.75
#
#  epoch:  12  Train error:      0.30  Train accuracy:    89.04 Val error:     0.38 Val accuracy:    86.78
#
#  epoch:  14  Train error:      0.29  Train accuracy:    89.38 Val error:     0.38 Val accuracy:    87.10
#
#  epoch:  16  Train error:      0.29  Train accuracy:    89.52 Val error:     0.39 Val accuracy:    87.20
#
#  epoch:  18  Train error:      0.28  Train accuracy:    89.82 Val error:     0.39 Val accuracy:    87.32
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='0.001 MB of 0.025 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=0.050728…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>accuracy_train</td><td>▁▃▄▅▆▆▆▆▇▇▇▇▇▇██████</td></tr><tr><td>accuracy_validation</td><td>▁▄▅▆▆▇▇▇▇▇▇█▇███████</td></tr><tr><td>cost_validation</td><td>█▄▃▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>epochs</td><td>▁▁▂▂▂▃▃▄▄▄▅▅▅▆▆▇▇▇██</td></tr><tr><td>loss_train</td><td>█▅▄▄▃▃▃▂▂▂▂▂▂▂▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>accuracy_train</td><td>89.95185</td></tr><tr><td>accuracy_validation</td><td>87.35</td></tr><tr><td>cost_validation</td><td>0.39489</td></tr><tr><td>epochs</td><td>19</td></tr><tr><td>loss_train</td><td>0.27504</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">magic-sweep-1</strong> at: <a href='https://wandb.ai/ananthu2014/CS6910_DL_ASS1/runs/gx1y65pl' target="_blank">https://wandb.ai/ananthu2014/CS6910_DL_ASS1/runs/gx1y65pl</a><br/>Synced 6 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>.\wandb\run-20230307_141047-gx1y65pl\logs</code>
# wandb: Agent Starting Run: o6mzvgqh with config:
# wandb: 	activation: relu_function
# wandb: 	batch_size: 16
# wandb: 	beta: 0.9
# wandb: 	beta1: 0.9
# wandb: 	beta2: 0.99
# wandb: 	epochs: 40
# wandb: 	lambd: 0
# wandb: 	learning_rate: 0.001
# wandb: 	loss: cross_entropy_function
# wandb: 	momentum: 0.9
# wandb: 	neurons: 64
# wandb: 	num_hidden_layers: 1
# wandb: 	optimizer: nadam
# wandb: 	weight_init: random_initialization
# Tracking run with wandb version 0.13.10
# Run data is saved locally in <code>C:\Users\anant\CS6910\Assignment 1\wandb\run-20230307_141343-o6mzvgqh</code>
# Syncing run <strong><a href='https://wandb.ai/ananthu2014/CS6910_DL_ASS1/runs/o6mzvgqh' target="_blank">fancy-sweep-2</a></strong> to <a href='https://wandb.ai/ananthu2014/CS6910_DL_ASS1' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>Sweep page: <a href='https://wandb.ai/ananthu2014/CS6910_DL_ASS1/sweeps/70xah3nu' target="_blank">https://wandb.ai/ananthu2014/CS6910_DL_ASS1/sweeps/70xah3nu</a>
#  View project at <a href='https://wandb.ai/ananthu2014/CS6910_DL_ASS1' target="_blank">https://wandb.ai/ananthu2014/CS6910_DL_ASS1</a>
#  View sweep at <a href='https://wandb.ai/ananthu2014/CS6910_DL_ASS1/sweeps/70xah3nu' target="_blank">https://wandb.ai/ananthu2014/CS6910_DL_ASS1/sweeps/70xah3nu</a>
#  View run at <a href='https://wandb.ai/ananthu2014/CS6910_DL_ASS1/runs/o6mzvgqh' target="_blank">https://wandb.ai/ananthu2014/CS6910_DL_ASS1/runs/o6mzvgqh</a>
# lr_0.001_acti_relu_function_w_inrandom_initialization_opt_nadam_epoch_40_num_hid_1_loss_cross_entropy_function_batchsize_16_neur_64_lam_0_momentum_0.9_beta_0.9_beta1_0.9_beta2_0.99
# neuron configuration: [784, 64, 10]
#
#  epoch:   0  Train error:      0.57  Train accuracy:    81.08 Val error:     0.61 Val accuracy:    79.70
#
#  epoch:   4  Train error:      0.37  Train accuracy:    86.91 Val error:     0.41 Val accuracy:    85.52
#
#  epoch:   8  Train error:      0.32  Train accuracy:    88.15 Val error:     0.39 Val accuracy:    86.48
#
#  epoch:  12  Train error:      0.30  Train accuracy:    89.04 Val error:     0.38 Val accuracy:    86.78
#
#  epoch:  16  Train error:      0.29  Train accuracy:    89.52 Val error:     0.39 Val accuracy:    87.20
#
#  epoch:  20  Train error:      0.27  Train accuracy:    90.05 Val error:     0.40 Val accuracy:    87.27
#
#  epoch:  24  Train error:      0.26  Train accuracy:    90.48 Val error:     0.41 Val accuracy:    87.55
#
#  epoch:  28  Train error:      0.25  Train accuracy:    90.76 Val error:     0.43 Val accuracy:    87.50
#
#  epoch:  32  Train error:      0.24  Train accuracy:    91.05 Val error:     0.44 Val accuracy:    87.20
#
#  epoch:  36  Train error:      0.24  Train accuracy:    91.26 Val error:     0.47 Val accuracy:    87.13
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='0.001 MB of 0.025 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=0.050729…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>accuracy_train</td><td>▁▃▄▅▅▅▅▆▆▆▆▆▆▆▇▇▇▇▇▇▇▇▇▇▇▇▇█████████████</td></tr><tr><td>accuracy_validation</td><td>▁▄▅▆▆▇▇▇▇▇▇▇▇▇██████████████████████████</td></tr><tr><td>cost_validation</td><td>█▄▃▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▂▂▂▂▂▂▂▂▃▃▃▃▃▃▃▄▄▄▄</td></tr><tr><td>epochs</td><td>▁▁▁▂▂▂▂▂▂▃▃▃▃▃▄▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>loss_train</td><td>█▆▅▄▄▃▃▃▃▃▃▃▂▂▂▂▂▂▂▂▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>accuracy_train</td><td>91.44444</td></tr><tr><td>accuracy_validation</td><td>87.1</td></tr><tr><td>cost_validation</td><td>0.48583</td></tr><tr><td>epochs</td><td>39</td></tr><tr><td>loss_train</td><td>0.23299</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">fancy-sweep-2</strong> at: <a href='https://wandb.ai/ananthu2014/CS6910_DL_ASS1/runs/o6mzvgqh' target="_blank">https://wandb.ai/ananthu2014/CS6910_DL_ASS1/runs/o6mzvgqh</a><br/>Synced 6 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>.\wandb\run-20230307_141343-o6mzvgqh\logs</code>
# wandb: Sweep Agent: Waiting for job.
# wandb: Sweep Agent: Exiting.

# %%
def neural_network_1(x_train,y_train,x_val,y_val,learning_rate = 0.1,momentum = 0.5,beta=0.5,beta1=0.5,beta2=0.5,epochs = 1,num_hidden_layers = 1,neurons=4,batch_size=4,epsilon=0.00000001,weight_init='random_initialization',
                   activation='sigmoid_function',loss='cross_entropy_function',optimizer='stochastic_gradient_descent',lambd=0):
#def neural_network():
    
#     # Default values for hyper-parameters
#     config_defaults = {
#         'learning_rate': 0.1,
#         'activation': 'sigmoid_function',
#         'weight_init': 'random_initialization',
#         'optimizer': 'stochastic_gradient_descent',
#         'batch_size': 4,
#         'epochs': 10,
#         'lambd': 0,
#         'neurons': 4,
#         'num_hidden_layers': 1,
#         'momentum':0.5,
#         'beta':0.5,
#         'beta1':0.5,
#         'beta2':0.5,
#         'loss':'cross_entropy_function'
#         }


#     wandb.init(config=config_defaults)
#     config = wandb.config

#     learning_rate = config.learning_rate
#     activation = config.activation
#     weight_init = config.weight_init
#     optimizer = config.optimizer
#     batch_size = config.batch_size
#     epochs = config.epochs
#     lambd = config.lambd
#     neurons = config.neurons
#     num_hidden_layers = config.num_hidden_layers
#     momentum=config.momentum
#     beta = config.beta
#     beta1=config.beta1
#     beta2=config.beta2
#     loss=config.loss
    
#     run_name= f'lr_{learning_rate}_acti_{activation}_w_in{weight_init}_opt_{optimizer}_epoch_{epochs}_num_hid_{num_hidden_layers}_loss_{loss}_batchsize_{batch_size}_neur_{neurons}_lam_{lambd}_momentum_{momentum}_beta_{beta}_beta1_{beta1}_beta2_{beta2}'
#     print(run_name)
    
    epsilon=0.00000001
    layer=[]
    n,m=x_train.shape
    J_train=[]
    Accuracy_train=[]
    J_val=[]
    Accuracy_val=[]
    acc_train=0
    acc_val=0
    layer.append(x_train.shape[0])
    for i in range(num_hidden_layers):
        layer.append(neurons)
    layer.append(y_train.shape[0])
    print(f'neuron configuration: {layer}')
    if weight_init=='random_initialization':
        w,b=random_initialization(layer)
    elif weight_init=='xavier_initialization':
        w,b=xavier_initialization(layer)
    update_w=[]
    update_b=[]
    w_lookahead=[]
    b_lookahead=[]
    v_t_w=[]
    v_t_b=[]
    m_w=[]
    m_b=[]
    v_w=[]
    v_b=[]
    for k in range(len(w)):
        upd_w=np.zeros((w[k].shape))
        upd_b=np.zeros((b[k].shape))
        update_w.append(upd_w)
        w_lookahead.append(upd_w)
        update_b.append(upd_b)
        b_lookahead.append(upd_b)
        v_t_w.append(upd_w)
        v_t_b.append(upd_b)
        m_w.append(upd_w)
        m_b.append(upd_b)
        v_w.append(upd_w)
        v_b.append(upd_b)
        
    num_batches = x_train.shape[1]//batch_size
    
    if optimizer=='vanilla_gradient_descent':
        
        for j in range(epochs):
            z,a = forward_propogation(x_train,w,b,activation)
            dz,dw,db=back_propogation(a,y_train,w,b,z,lambd,activation,loss)
            w,b=gradient_descent(w,b,dw,db,learning_rate)
            if loss=='cross_entropy_function':
                
                cost_train=cross_entropy_function(y_train,a[-1],w,lambd)
                J_train.append(cost_train)
                acc_train = accuracy(y_train,a[-1])
                Accuracy_train.append(acc_train)
                z_val,a_val = forward_propogation(x_val,w,b,activation)
                cost_val = cross_entropy_function(y_val,a_val[-1],w,lambd)
                J_val.append(cost_val)
                acc_val=accuracy(y_val,a_val[-1])
                Accuracy_val.append(acc_val)
            elif loss=='mean_squared_error_function':
                
                cost_train=mean_squared_error_function(y_train,a[-1],w,lambd)
                J_train.append(cost_train)
                acc_train = accuracy(y_train,a[-1])
                Accuracy_train.append(acc_train)
                z_val,a_val = forward_propogation(x_val,w,b,activation)
                cost_val = mean_squared_error_function(y_val,a_val[-1],w,lambd)
                J_val.append(cost_val)
                acc_val = accuracy(y_val,a_val[-1])
                Accuracy_val.append(acc_val)
            wandb.log({"accuracy_train": acc_train, "accuracy_validation": acc_val, "loss_train": cost_train, "cost_validation": cost_val, 'epochs': j})
            
            if j%(epochs/10)==0:
                print(f' \n epoch:{j:4d}  Train error:  {J_train[-1]:8.2f}  Train accuracy: {Accuracy_train[-1]:8.2f} Val error: {J_val[-1]:8.2f} Val accuracy: {Accuracy_val[-1]:8.2f}')
            #if j%((epochs/10)/5)==0:
                #print('==',end='')
            
    if optimizer=='stochastic_gradient_descent':
        
        
        for j in range(epochs):
            for i in range(m):
                x_data = x_train[:,i].reshape(x_train.shape[0],1)
                y_data = y_train[:,i].reshape(y_train.shape[0],1)
                z,a = forward_propogation(x_data,w,b,activation)
                dz,dw,db=back_propogation(a,y_data,w,b,z,lambd,activation,loss)
                w,b=gradient_descent(w,b,dw,db,learning_rate)
            z,a = forward_propogation(x_train,w,b,activation)
            cost_train=cross_entropy_function(y_train,a[-1],w,lambd)
            J_train.append(cost_train)
            acc_train = accuracy(y_train,a[-1])
            Accuracy_train.append(acc_train)
            z_val,a_val = forward_propogation(x_val,w,b,activation)
            cost_val = cross_entropy_function(y_val,a_val[-1],w,lambd)
            J_val.append(cost_val)
            acc_val = accuracy(y_val,a_val[-1])
            wandb.log({"accuracy_train": acc_train, "accuracy_validation": acc_val, "loss_train": cost_train, "cost_validation": cost_val, 'epochs': j})
            Accuracy_val.append(acc_val)
            if j%(epochs/10)==0:
                print(f' \n epoch:{j:4d}  Train error:  {J_train[-1]:8.2f}  Train accuracy: {Accuracy_train[-1]:8.2f} Val error: {J_val[-1]:8.2f} Val accuracy: {Accuracy_val[-1]:8.2f}')
            #if j%((epochs/10)/5)==0:
                #print('==',end='')
            
    if optimizer=='momentum_gradient_descent':
            
        for j in range(epochs):
            
            for i in range(num_batches):
                x_mb = x_train[:,i*batch_size:(i+1)*batch_size].reshape(x_train.shape[0],batch_size)
                y_mb = y_train[:,i*batch_size:(i+1)*batch_size].reshape(y_train.shape[0],batch_size)
                z,a = forward_propogation(x_mb,w,b,activation)
                dz,dw,db=back_propogation(a,y_mb,w,b,z,lambd,activation,loss)
                w,b,update_w,update_b = momentum_gradient_descent(w,b,dw,db,learning_rate,momentum,update_w,update_b)
            if x_train.shape[1] % batch_size !=0:
                x_last = x_train[:,num_batches*batch_size:]
                y_last = y_train[:,num_batches*batch_size:]
                z,a = forward_propogation(x_last,w,b,activation)
                dz,dw,db=back_propogation(a,y_last,w,b,z,lambd,activation,loss)
                w,b,update_w,update_b = momentum_gradient_descent(w,b,dw,db,learning_rate,momentum,update_w,update_b)
            z,a = forward_propogation(x_train,w,b,activation)
            if loss=='cross_entropy_function':
                
                cost_train=cross_entropy_function(y_train,a[-1],w,lambd)
                J_train.append(cost_train)
                acc_train = accuracy(y_train,a[-1])
                Accuracy_train.append(acc_train)
                z_val,a_val = forward_propogation(x_val,w,b,activation)
                cost_val = cross_entropy_function(y_val,a_val[-1],w,lambd)
                J_val.append(cost_val)
                acc_val=accuracy(y_val,a_val[-1])
                Accuracy_val.append(acc_val)
            elif loss=='mean_squared_error_function':
                
                cost_train=mean_squared_error_function(y_train,a[-1],w,lambd)
                J_train.append(cost_train)
                acc_train = accuracy(y_train,a[-1])
                Accuracy_train.append(acc_train)
                z_val,a_val = forward_propogation(x_val,w,b,activation)
                cost_val = mean_squared_error_function(y_val,a_val[-1],w,lambd)
                J_val.append(cost_val)
                acc_val = accuracy(y_val,a_val[-1])
                Accuracy_val.append(acc_val)
            wandb.log({"accuracy_train": acc_train, "accuracy_validation": acc_val, "loss_train": cost_train, "cost_validation": cost_val, 'epochs': j})
            
            if j%(epochs/10)==0:
                print(f' \n epoch:{j:4d}  Train error:  {J_train[-1]:8.2f}  Train accuracy: {Accuracy_train[-1]:8.2f} Val error: {J_val[-1]:8.2f} Val accuracy: {Accuracy_val[-1]:8.2f}')
            #if j%((epochs/10)/5)==0:
                #print('==',end='')
                
                
    if optimizer == 'nesterov_accelarated_gradient_descent':
        
        for j in range(epochs):
            
            for i in range(num_batches):
                x_mb = x_train[:,i*batch_size:(i+1)*batch_size].reshape(x_train.shape[0],batch_size)
                y_mb = y_train[:,i*batch_size:(i+1)*batch_size].reshape(y_train.shape[0],batch_size)
                for i in range(len(w)):
                    w_lookahead[i] = w[i]-momentum*update_w[i]
                    b_lookahead[i] = b[i]-momentum*update_b[i]
                z,a = forward_propogation(x_mb,w_lookahead,b_lookahead,activation)
                dz,dw,db=back_propogation(a,y_mb,w_lookahead,b_lookahead,z,lambd,activation,loss)
                w,b,update_w,update_b = momentum_gradient_descent(w,b,dw,db,learning_rate,momentum,update_w,update_b)
            if x_train.shape[1] % batch_size !=0:
                x_last = x_train[:,num_batches*batch_size:]
                y_last = y_train[:,num_batches*batch_size:]
                z,a = forward_propogation(x_last,w_lookahead,b_lookahead,activation)
                dz,dw,db=back_propogation(a,y_last,w_lookahead,b_lookahead,z,lambd,activation,loss)
                w,b,update_w,update_b = momentum_gradient_descent(w,b,dw,db,learning_rate,momentum,update_w,update_b)
                
            z,a = forward_propogation(x_train,w,b,activation)
            if loss=='cross_entropy_function':
                
                cost_train=cross_entropy_function(y_train,a[-1],w,lambd)
                J_train.append(cost_train)
                acc_train = accuracy(y_train,a[-1])
                Accuracy_train.append(acc_train)
                z_val,a_val = forward_propogation(x_val,w,b,activation)
                cost_val = cross_entropy_function(y_val,a_val[-1],w,lambd)
                J_val.append(cost_val)
                acc_val=accuracy(y_val,a_val[-1])
                Accuracy_val.append(acc_val)
            elif loss=='mean_squared_error_function':
                
                cost_train=mean_squared_error_function(y_train,a[-1],w,lambd)
                J_train.append(cost_train)
                acc_train = accuracy(y_train,a[-1])
                Accuracy_train.append(acc_train)
                z_val,a_val = forward_propogation(x_val,w,b,activation)
                cost_val = mean_squared_error_function(y_val,a_val[-1],w,lambd)
                J_val.append(cost_val)
                acc_val = accuracy(y_val,a_val[-1])
                Accuracy_val.append(acc_val)
            wandb.log({"accuracy_train": acc_train, "accuracy_validation": acc_val, "loss_train": cost_train, "cost_validation": cost_val, 'epochs': j})
            
            if j%(epochs/10)==0:
                print(f' \n epoch:{j:4d}  Train error:  {J_train[-1]:8.2f}  Train accuracy: {Accuracy_train[-1]:8.2f} Val error: {J_val[-1]:8.2f} Val accuracy: {Accuracy_val[-1]:8.2f}')
            #if j%((epochs/10)/5)==0:
                #print('==',end='')
                
                
    if optimizer == 'rms_prop':
            
        for j in range(epochs):
            
            for i in range(num_batches):
                x_mb = x_train[:,i*batch_size:(i+1)*batch_size].reshape(x_train.shape[0],batch_size)
                y_mb = y_train[:,i*batch_size:(i+1)*batch_size].reshape(y_train.shape[0],batch_size)
                z,a = forward_propogation(x_mb,w,b,activation)
                dz,dw,db=back_propogation(a,y_mb,w,b,z,lambd,activation,loss)
                w,b,v_t_w,v_t_b = rms_prop(w,b,dw,db,learning_rate,beta,epsilon,v_t_w,v_t_b)
            if x_train.shape[1] % batch_size !=0:
                x_last = x_train[:,num_batches*batch_size:]
                y_last = y_train[:,num_batches*batch_size:]
                z,a = forward_propogation(x_last,w,b,activation)
                dz,dw,db=back_propogation(a,y_last,w,b,z,lambd,activation,loss)
                w,b,v_t_w,v_t_b = rms_prop(w,b,dw,db,learning_rate,beta,epsilon,v_t_w,v_t_b)
            z,a = forward_propogation(x_train,w,b,activation)
            if loss=='cross_entropy_function':
                
                cost_train=cross_entropy_function(y_train,a[-1],w,lambd)
                J_train.append(cost_train)
                acc_train = accuracy(y_train,a[-1])
                Accuracy_train.append(acc_train)
                z_val,a_val = forward_propogation(x_val,w,b,activation)
                cost_val = cross_entropy_function(y_val,a_val[-1],w,lambd)
                J_val.append(cost_val)
                acc_val=accuracy(y_val,a_val[-1])
                Accuracy_val.append(acc_val)
            elif loss=='mean_squared_error_function':
                
                cost_train=mean_squared_error_function(y_train,a[-1],w,lambd)
                J_train.append(cost_train)
                acc_train = accuracy(y_train,a[-1])
                Accuracy_train.append(acc_train)
                z_val,a_val = forward_propogation(x_val,w,b,activation)
                cost_val = mean_squared_error_function(y_val,a_val[-1],w,lambd)
                J_val.append(cost_val)
                acc_val = accuracy(y_val,a_val[-1])
                Accuracy_val.append(acc_val)
            wandb.log({"accuracy_train": acc_train, "accuracy_validation": acc_val, "loss_train": cost_train, "cost_validation": cost_val, 'epochs': j})
            
            if j%(epochs/10)==0:
                print(f' \n epoch:{j:4d}  Train error:  {J_train[-1]:8.2f}  Train accuracy: {Accuracy_train[-1]:8.2f} Val error: {J_val[-1]:8.2f} Val accuracy: {Accuracy_val[-1]:8.2f}')
            #if j%((epochs/10)/5)==0:
                #print('==',end='')
                
                
                
    if optimizer == 'adam':
        for  j in range(epochs):
            
            for i in range(num_batches):
                x_mb = x_train[:,i*batch_size:(i+1)*batch_size].reshape(x_train.shape[0],batch_size)
                y_mb = y_train[:,i*batch_size:(i+1)*batch_size].reshape(y_train.shape[0],batch_size)
                z,a = forward_propogation(x_mb,w,b,activation)
                dz,dw,db=back_propogation(a,y_mb,w,b,z,lambd,activation,loss)
                w,b,m_w,m_b,v_w,v_b = adam(w,b,dw,db,learning_rate,beta1,beta2,epsilon,m_w,m_b,v_w,v_b,j+1)
            if x_train.shape[1] % batch_size !=0:
                x_last = x_train[:,num_batches*batch_size:]
                y_last = y_train[:,num_batches*batch_size:]
                z,a = forward_propogation(x_last,w,b,activation)
                dz,dw,db=back_propogation(a,y_last,w,b,z,lambd,activation,loss)
                w,b,m_w,m_b,v_w,v_b = adam(w,b,dw,db,learning_rate,beta1,beta2,epsilon,m_w,m_b,v_w,v_b,j+1)
            z,a=forward_propogation(x_train,w,b,activation)
            if loss=='cross_entropy_function':
                
                cost_train=cross_entropy_function(y_train,a[-1],w,lambd)
                J_train.append(cost_train)
                acc_train = accuracy(y_train,a[-1])
                Accuracy_train.append(acc_train)
                z_val,a_val = forward_propogation(x_val,w,b,activation)
                cost_val = cross_entropy_function(y_val,a_val[-1],w,lambd)
                J_val.append(cost_val)
                acc_val=accuracy(y_val,a_val[-1])
                Accuracy_val.append(acc_val)
            elif loss=='mean_squared_error_function':
                
                cost_train=mean_squared_error_function(y_train,a[-1],w,lambd)
                J_train.append(cost_train)
                acc_train = accuracy(y_train,a[-1])
                Accuracy_train.append(acc_train)
                z_val,a_val = forward_propogation(x_val,w,b,activation)
                cost_val = mean_squared_error_function(y_val,a_val[-1],w,lambd)
                J_val.append(cost_val)
                acc_val = accuracy(y_val,a_val[-1])
                Accuracy_val.append(acc_val)
            wandb.log({"accuracy_train": acc_train, "accuracy_validation": acc_val, "loss_train": cost_train, "cost_validation": cost_val, 'epochs': j})
            
            if j%(epochs/10)==0:
                print(f' \n epoch:{j:4d}  Train error:  {J_train[-1]:8.2f}  Train accuracy: {Accuracy_train[-1]:8.2f} Val error: {J_val[-1]:8.2f} Val accuracy: {Accuracy_val[-1]:8.2f}')
            #if j%((epochs/10)/5)==0:
                #print('==',end='')
                
                
    if optimizer =='nadam':
        for  j in range(epochs):
            
            for i in range(num_batches):
                x_mb = x_train[:,i*batch_size:(i+1)*batch_size].reshape(x_train.shape[0],batch_size)
                y_mb = y_train[:,i*batch_size:(i+1)*batch_size].reshape(y_train.shape[0],batch_size)
                z,a = forward_propogation(x_mb,w,b,activation)
                dz,dw,db=back_propogation(a,y_mb,w,b,z,lambd,activation,loss)
                w,b,m_w,m_b,v_w,v_b = nadam(w,b,dw,db,learning_rate,beta1,beta2,epsilon,m_w,m_b,v_w,v_b,j+1)
            if x_train.shape[1] % batch_size !=0:
                x_last = x_train[:,num_batches*batch_size:]
                y_last = y_train[:,num_batches*batch_size:]
                z,a = forward_propogation(x_last,w,b,activation)
                dz,dw,db=back_propogation(a,y_last,w,b,z,lambd,activation,loss)
                w,b,m_w,m_b,v_w,v_b = nadam(w,b,dw,db,learning_rate,beta1,beta2,epsilon,m_w,m_b,v_w,v_b,j+1)
            z,a=forward_propogation(x_train,w,b,activation)
            
            if loss=='cross_entropy_function':
                
                cost_train=cross_entropy_function(y_train,a[-1],w,lambd)
                J_train.append(cost_train)
                acc_train = accuracy(y_train,a[-1])
                Accuracy_train.append(acc_train)
                z_val,a_val = forward_propogation(x_val,w,b,activation)
                cost_val = cross_entropy_function(y_val,a_val[-1],w,lambd)
                J_val.append(cost_val)
                acc_val=accuracy(y_val,a_val[-1])
                Accuracy_val.append(acc_val)
            elif loss=='mean_squared_error_function':
                
                cost_train=mean_squared_error_function(y_train,a[-1],w,lambd)
                J_train.append(cost_train)
                acc_train = accuracy(y_train,a[-1])
                Accuracy_train.append(acc_train)
                z_val,a_val = forward_propogation(x_val,w,b,activation)
                cost_val = mean_squared_error_function(y_val,a_val[-1],w,lambd)
                J_val.append(cost_val)
                acc_val = accuracy(y_val,a_val[-1])
                Accuracy_val.append(acc_val)
            #wandb.log({"accuracy_train": acc_train, "accuracy_validation": acc_val, "loss_train": cost_train, "cost_validation": cost_val, 'epochs': j})
            
            if j%(epochs/10)==0:
                print(f' \n epoch:{j:4d}  Train error:  {J_train[-1]:8.2f}  Train accuracy: {Accuracy_train[-1]:8.2f} Val error: {J_val[-1]:8.2f} Val accuracy: {Accuracy_val[-1]:8.2f}')
            #if j%((epochs/10)/5)==0:
                #print('==',end='')
        
            
            
    plot_error(J_train,J_val)
    plot_accuracy(Accuracy_train,Accuracy_val)
    return w,b
    
#     wandb.run.name = run_name
#     wandb.run.save()
#     wandb.run.finish()

# %%
'''LEARNING RATE:0.001
EPOCHS:20
OPTIMIZER:Nesterov Adam
REGULARIZATION PARAMETER:0
ACTIVATION FUNCTION:RELu function
BETA1:0.9
BETA2:0.99
INITIALIZATION:RANDOM
LOSS FUNCTION:CROSS-ENTROPY
BATCH SIZE:16
NEURONS:64
HIDDEN LAYERS:1'''
w_max,b_max=neural_network_1(x_train,y_train,x_val,y_val,learning_rate=0.001,epochs=20,activation='relu_function',optimizer='adam',loss='cross_entropy_function',
                                        batch_size=16,num_hidden_layers=1,neurons=64,lambd=0,epsilon=0.00000001)
# Out:
# neuron configuration: [784, 64, 10]
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_13272\1775749083.py in <module>
#      11 NEURONS:64
#      12 HIDDEN LAYERS:1'''
# ---> 13 w_max,b_max=neural_network_1(x_train,y_train,x_val,y_val,learning_rate=0.001,epochs=20,activation='relu_function',optimizer='adam',loss='cross_entropy_function',
#      14                                         batch_size=16,num_hidden_layers=1,neurons=64,lambd=0,epsilon=0.00000001)
#
# ~\AppData\Local\Temp\ipykernel_13272\93539668.py in neural_network_1(x_train, y_train, x_val, y_val, learning_rate, momentum, beta, beta1, beta2, epochs, num_hidden_layers, neurons, batch_size, epsilon, weight_init, activation, loss, optimizer, lambd)
#     301                 y_mb = y_train[:,i*batch_size:(i+1)*batch_size].reshape(y_train.shape[0],batch_size)
#     302                 z,a = forward_propogation(x_mb,w,b,activation)
# --> 303                 dz,dw,db=back_propogation(a,y_mb,w,b,z,lambd,activation,loss)
#     304                 w,b,m_w,m_b,v_w,v_b = adam(w,b,dw,db,learning_rate,beta1,beta2,epsilon,m_w,m_b,v_w,v_b,j+1)
#     305             if x_train.shape[1] % batch_size !=0:
#
# NameError: name 'back_propogation' is not defined

# %%
w,b,J_train_max,J_val_max=neural_network(x_train,y_train,x_val,y_val,learning_rate=0.001,epochs=20,activation='relu_function',optimizer='nadam',loss='cross_entropy_function',
                                        batch_size=16,num_hidden_layers=1,neurons=64,lambd=0.0,epsilon=0.00000001)
# Out:
# neuron configuration: [784, 64, 10]
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_13272\4080868338.py in <module>
# ----> 1 w,b,J_train_max,J_val_max=neural_network(x_train,y_train,x_val,y_val,learning_rate=0.001,epochs=20,activation='relu_function',optimizer='nadam',loss='cross_entropy_function',
#       2                                         batch_size=16,num_hidden_layers=1,neurons=64,lambd=0.0,epsilon=0.00000001)
#
# ~\AppData\Local\Temp\ipykernel_13272\1868887588.py in neural_network(x_train, y_train, x_val, y_val, learning_rate, momentum, beta, beta1, beta2, epochs, num_hidden_layers, neurons, batch_size, epsilon, weight_init, activation, loss, optimizer, lambd)
#     347                 y_mb = y_train[:,i*batch_size:(i+1)*batch_size].reshape(y_train.shape[0],batch_size)
#     348                 z,a = forward_propogation(x_mb,w,b,activation)
# --> 349                 dz,dw,db=back_propogation(a,y_mb,w,b,z,lambd,activation,loss)
#     350                 w,b,m_w,m_b,v_w,v_b = nadam(w,b,dw,db,learning_rate,beta1,beta2,epsilon,m_w,m_b,v_w,v_b,j+1)
#     351             if x_train.shape[1] % batch_size !=0:
#
# NameError: name 'back_propogation' is not defined

# %%
#y_pred,Y,acc=predict(x_val,y_val,w_max,b_max,lambd=0.0,activation='relu_function')
#print(acc)
z,a=forward_propogation(x_val,w_max,b_max,activation='relu_function')
y_pred=a[-1]
Y_pred=np.argmax(y_pred,axis=0)
Y=np.argmax(y_val,axis=0)
acc=np.mean(Y_pred==Y)*100
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_13272\2743202683.py in <module>
#       1 #y_pred,Y,acc=predict(x_val,y_val,w_max,b_max,lambd=0.0,activation='relu_function')
#       2 #print(acc)
# ----> 3 z,a=forward_propogation(x_val,w_max,b_max,activation='relu_function')
#       4 y_pred=a[-1]
#       5 Y_pred=np.argmax(y_pred,axis=0)
#
# NameError: name 'w_max' is not defined

# %%
import seaborn as sns
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt
import numpy as np
cm = confusion_matrix(Y, Y_pred)
fig, ax = plt.subplots()
sns.heatmap(cm, annot=True, cmap="binary", fmt='g', ax=ax,xticklabels=['T-shirt','Trouser','Pullover','Skirt',
    'Overcoat','Sandal','Shirt','Sneakers','Bag','Ankle boot'],yticklabels=['T-shirt','Trouser','Pullover','Skirt',
                                                        'Overcoat','Sandal','Shirt','Sneakers','Bag','Ankle boot'])
ax.set_xlabel("Predicted labels")
ax.set_ylabel("True labels")
ax.set_title("Confusion Matrix")

plt.show()

# %%
wandb.init(project="CS6910_DL_ASS1", name='CONFUSION MATRIX')

wandb.log({"conf_mat" : wandb.plot.confusion_matrix(probs=None,
                        y_true=Y, preds=Y_pred,class_names=['T-shirt','Trouser','Pullover','Skirt',
                                                        'Overcoat','Sandal','Shirt','Sneakers','Bag','Ankle boot'])})
# Out:
# Finishing last run (ID:qrn4j6oi) before initializing another...
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='0.001 MB of 0.023 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=0.054589…
#  View run <strong style="color:#cdcd00">CONFUSION MATRIX</strong> at: <a href='https://wandb.ai/ananthu2014/CS6910_DL_ASS1/runs/qrn4j6oi' target="_blank">https://wandb.ai/ananthu2014/CS6910_DL_ASS1/runs/qrn4j6oi</a><br/>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>.\wandb\run-20230308_065920-qrn4j6oi\logs</code>
# Successfully finished last run (ID:qrn4j6oi). Initializing new run:<br/>
# VBox(children=(Label(value='Waiting for wandb.init()...\r'), FloatProgress(value=0.017200000000108653, max=1.0…
# wandb version 0.13.11 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.13.10
# Run data is saved locally in <code>C:\Users\anant\CS6910\Assignment 1\wandb\run-20230308_070030-52i1zkv0</code>
# Syncing run <strong><a href='https://wandb.ai/ananthu2014/CS6910_DL_ASS1/runs/52i1zkv0' target="_blank">CONFUSION MATRIX</a></strong> to <a href='https://wandb.ai/ananthu2014/CS6910_DL_ASS1' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/ananthu2014/CS6910_DL_ASS1' target="_blank">https://wandb.ai/ananthu2014/CS6910_DL_ASS1</a>
#  View run at <a href='https://wandb.ai/ananthu2014/CS6910_DL_ASS1/runs/52i1zkv0' target="_blank">https://wandb.ai/ananthu2014/CS6910_DL_ASS1/runs/52i1zkv0</a>

# %%
sweep_config = {
  "name": "Loss and Accuracy-Highest validation accuracy",
  "metric": {
      "name":"accuracy_validation",
      "goal": "maximize"
  },
  "method": "grid",
  "parameters": {
        "learning_rate": {
            "values": [0.001]
        },
        "activation": {
            "values": ["relu_function"]
        },
        "weight_init": {
            "values": ["random_initialization"]
        },
        "optimizer": {
            "values": ["nadam"]
        },
        "batch_size": {
            "values": [16]
        },
        "epochs": {
            "values": [20]
        },
        "lambd": {
            "values": [0]
        },
        "neurons": {
            "values": [64]
        },
        "num_hidden_layers": {
            "values": [1]
        },
        "momentum": {
            "values": [0.9]
        },
        "beta": {
            "values": [0.9]
        },
        "beta1": {
            "values": [0.9]
        },
        "beta2": {
            "values": [0.99]
        },
        "loss": {
            "values": ['cross_entropy_function','mean_squared_error_function']
        }
    }
}

sweep_id = wandb.sweep(sweep_config, project="CS6910_DL_ASS1")
wandb.agent(sweep_id, neural_network)
# Out:
# Create sweep with ID: d7bqdqji
# Sweep URL: https://wandb.ai/ananthu2014/CS6910_DL_ASS1/sweeps/d7bqdqji
# wandb: Agent Starting Run: il53f456 with config:
# wandb: 	activation: relu_function
# wandb: 	batch_size: 16
# wandb: 	beta: 0.9
# wandb: 	beta1: 0.9
# wandb: 	beta2: 0.99
# wandb: 	epochs: 20
# wandb: 	lambd: 0
# wandb: 	learning_rate: 0.001
# wandb: 	loss: cross_entropy_function
# wandb: 	momentum: 0.9
# wandb: 	neurons: 64
# wandb: 	num_hidden_layers: 1
# wandb: 	optimizer: nadam
# wandb: 	weight_init: random_initialization
# wandb version 0.13.11 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.13.10
# Run data is saved locally in <code>C:\Users\anant\CS6910\Assignment 1\wandb\run-20230308_111341-il53f456</code>
# Syncing run <strong><a href='https://wandb.ai/ananthu2014/CS6910_DL_ASS1/runs/il53f456' target="_blank">distinctive-sweep-1</a></strong> to <a href='https://wandb.ai/ananthu2014/CS6910_DL_ASS1' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>Sweep page: <a href='https://wandb.ai/ananthu2014/CS6910_DL_ASS1/sweeps/d7bqdqji' target="_blank">https://wandb.ai/ananthu2014/CS6910_DL_ASS1/sweeps/d7bqdqji</a>
#  View project at <a href='https://wandb.ai/ananthu2014/CS6910_DL_ASS1' target="_blank">https://wandb.ai/ananthu2014/CS6910_DL_ASS1</a>
#  View sweep at <a href='https://wandb.ai/ananthu2014/CS6910_DL_ASS1/sweeps/d7bqdqji' target="_blank">https://wandb.ai/ananthu2014/CS6910_DL_ASS1/sweeps/d7bqdqji</a>
#  View run at <a href='https://wandb.ai/ananthu2014/CS6910_DL_ASS1/runs/il53f456' target="_blank">https://wandb.ai/ananthu2014/CS6910_DL_ASS1/runs/il53f456</a>
# lr_0.001_acti_relu_function_w_inrandom_initialization_opt_nadam_epoch_20_num_hid_1_loss_cross_entropy_function_batchsize_16_neur_64_lam_0_momentum_0.9_beta_0.9_beta1_0.9_beta2_0.99
# neuron configuration: [784, 64, 10]
# Waiting for W&B process to finish... <strong style="color:red">(failed 1).</strong> Press Ctrl-C to abort syncing.
#  View run <strong style="color:#cdcd00">distinctive-sweep-1</strong> at: <a href='https://wandb.ai/ananthu2014/CS6910_DL_ASS1/runs/il53f456' target="_blank">https://wandb.ai/ananthu2014/CS6910_DL_ASS1/runs/il53f456</a><br/>Synced 6 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>.\wandb\run-20230308_111341-il53f456\logs</code>
# Run il53f456 errored: TypeError('back_propogation() takes from 6 to 7 positional arguments but 8 were given')
# wandb: ERROR Run il53f456 errored: TypeError('back_propogation() takes from 6 to 7 positional arguments but 8 were given')
# wandb: Agent Starting Run: ph7txhz7 with config:
# wandb: 	activation: relu_function
# wandb: 	batch_size: 16
# wandb: 	beta: 0.9
# wandb: 	beta1: 0.9
# wandb: 	beta2: 0.99
# wandb: 	epochs: 20
# wandb: 	lambd: 0
# wandb: 	learning_rate: 0.001
# wandb: 	loss: mean_squared_error_function
# wandb: 	momentum: 0.9
# wandb: 	neurons: 64
# wandb: 	num_hidden_layers: 1
# wandb: 	optimizer: nadam
# wandb: 	weight_init: random_initialization
# wandb version 0.13.11 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.13.10
# Run data is saved locally in <code>C:\Users\anant\CS6910\Assignment 1\wandb\run-20230308_111414-ph7txhz7</code>
# Syncing run <strong><a href='https://wandb.ai/ananthu2014/CS6910_DL_ASS1/runs/ph7txhz7' target="_blank">royal-sweep-2</a></strong> to <a href='https://wandb.ai/ananthu2014/CS6910_DL_ASS1' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>Sweep page: <a href='https://wandb.ai/ananthu2014/CS6910_DL_ASS1/sweeps/d7bqdqji' target="_blank">https://wandb.ai/ananthu2014/CS6910_DL_ASS1/sweeps/d7bqdqji</a>
#  View project at <a href='https://wandb.ai/ananthu2014/CS6910_DL_ASS1' target="_blank">https://wandb.ai/ananthu2014/CS6910_DL_ASS1</a>
#  View sweep at <a href='https://wandb.ai/ananthu2014/CS6910_DL_ASS1/sweeps/d7bqdqji' target="_blank">https://wandb.ai/ananthu2014/CS6910_DL_ASS1/sweeps/d7bqdqji</a>
#  View run at <a href='https://wandb.ai/ananthu2014/CS6910_DL_ASS1/runs/ph7txhz7' target="_blank">https://wandb.ai/ananthu2014/CS6910_DL_ASS1/runs/ph7txhz7</a>
# lr_0.001_acti_relu_function_w_inrandom_initialization_opt_nadam_epoch_20_num_hid_1_loss_mean_squared_error_function_batchsize_16_neur_64_lam_0_momentum_0.9_beta_0.9_beta1_0.9_beta2_0.99
# neuron configuration: [784, 64, 10]
# Waiting for W&B process to finish... <strong style="color:red">(failed 1).</strong> Press Ctrl-C to abort syncing.
#  View run <strong style="color:#cdcd00">royal-sweep-2</strong> at: <a href='https://wandb.ai/ananthu2014/CS6910_DL_ASS1/runs/ph7txhz7' target="_blank">https://wandb.ai/ananthu2014/CS6910_DL_ASS1/runs/ph7txhz7</a><br/>Synced 6 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>.\wandb\run-20230308_111414-ph7txhz7\logs</code>
# Run ph7txhz7 errored: TypeError('back_propogation() takes from 6 to 7 positional arguments but 8 were given')
# wandb: ERROR Run ph7txhz7 errored: TypeError('back_propogation() takes from 6 to 7 positional arguments but 8 were given')
# wandb: Sweep Agent: Waiting for job.
# wandb: Sweep Agent: Exiting.
